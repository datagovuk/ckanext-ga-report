# %%
# Monthly
# -------
# BANNER     Visitors this month
# A/B BAR    %new visitors this month
# ICONS      Avg.Pageviews per visitor 
# BANNER     %BounceRate
# BANNER     Avg.Time on site
# LINECHART  Pageviews Per Daydal pankcakdeal p
# PIECHART   Browser[Name,Version]
# PIECHART   OperatingSystem[Name,Version]
# PIECHART   Country
# PIECHART   Language

# Over Site Lifetime
# ------------------
# Pageviews per month
# Top Dataset   (how to be useful?)
# Top Publisher (how to be useful?)

# %%
from random import randint
def randomLetter():
    from string import lowercase
    return lowercase[randint(0,25)]
    
def randomSeries(name):
    return {'name':name, 'value':randint(0,99)}
    
def randomPie(numseries=3):
    return [ randomSeries(("entry%d"%i)) for i in range(numseries) ]

def randomMonth(datename):
    return { 'datename':datename, 'pie1':randomPie(4), 'pie2':randomPie(randint(2,4)), 'pie3':randomPie(18), 'pie4':randomPie(8),  }

import json
jsondata = {
    'hello':'world',
    'monthlydata' : [ randomMonth('March 2012'), randomMonth('April 2012'), randomMonth('May 2012'), randomMonth('June 2012'), ]
}
# Pie charts should all have the same series in the same order, so add some zero padding.
def normalizePieCharts(pies):
    series = ['entry0','entry1','entry2','entry3']
    def getEntry(name,entries):
        for x in entries:
            if x['name']==name: return x
        return {'name':name,'value':0}
    # Update the pie chart in-place
    for pie in pies:
        tmp = [ pie.pop() for i in range(len(pie)) ]
        for name in series:
            pie.append( getEntry(name,tmp) )
# Experiment with variable series: Some series do not appear here
p = jsondata['monthlydata'][0]['pie1']  ;  p.remove(p[0])
p = jsondata['monthlydata'][2]['pie1']  ;  p.remove(p[2])
for name in ['pie1','pie2','pie3','pie4']:
    normalizePieCharts( [ x[name] for x in jsondata['monthlydata'] ] )
with open('ckanext/ga_report/public/scripts/json/ga_reports.json','w') as f:
    json.dump(jsondata,f)

# %%
import pandas
# !ls *.csv
# Out:
# publishers_all.csv stats_all.csv

# %%
df = pandas.read_csv('stats_all.csv')
df.head()
# Out:
#     Period         Statistic                  Key  Value
# 0  2012-07  Browser versions  Android Browser 53X   3823
# 1  2012-07  Browser versions            Chrome 10    204
# 2  2012-07  Browser versions            Chrome 11    217
# 3  2012-07  Browser versions            Chrome 12    460
# 4  2012-07  Browser versions            Chrome 13    132
#
# [5 rows x 4 columns]

# %%
df['Statistic'].unique()
# Out:
# array(['Browser versions', 'Browsers', 'Country', 'Languages',
#        'Mobile brands', 'Mobile devices', 'Operating Systems',
#        'Operating Systems versions', 'Social sources', 'Totals'], dtype=object)

# %%
browsers = df[ df['Statistic']=='Browser versions' ]
indexed = browsers.set_index(['Period'])[['Key','Value']]
indexed
# Out:
#                                 Key  Value
# Period
# 2012-07         Android Browser 53X   3823
# 2012-07                   Chrome 10    204
# 2012-07                   Chrome 11    217
# 2012-07                   Chrome 12    460
# 2012-07                   Chrome 13    132
# 2012-07                   Chrome 14    200
# 2012-07                   Chrome 15    372
# 2012-07                   Chrome 16    574
# 2012-07                   Chrome 17   1146
# 2012-07                   Chrome 18   2798
# 2012-07                   Chrome 19   8777
# 2012-07                   Chrome 20  83784
# 2012-07                   Chrome 21   1129
# 2012-07                   Chrome 22    527
# 2012-07                    Chrome 6    116
# 2012-07                    Chrome 7     83
# 2012-07                    Chrome 8    137
# 2012-07                  Firefox 10   3751
# 2012-07                  Firefox 11   1666
# 2012-07                  Firefox 12   5072
# 2012-07                  Firefox 13  34731
# 2012-07                  Firefox 14  13408
# 2012-07                  Firefox 15    346
# 2012-07                  Firefox 16    129
# 2012-07                   Firefox 3   4238
# 2012-07                   Firefox 4    899
# 2012-07                   Firefox 5    895
# 2012-07                   Firefox 6    565
# 2012-07                   Firefox 7    884
# 2012-07                   Firefox 8    717
# 2012-07                   Firefox 9   1001
# 2012-07      IE with Chrome Frame 7    264
# 2012-07      IE with Chrome Frame 8    531
# 2012-07        Internet Explorer 10    371
# 2012-07         Internet Explorer 6   6025
# 2012-07         Internet Explorer 7  38575
# 2012-07         Internet Explorer 8  82058
# 2012-07         Internet Explorer 9  45543
# 2012-07  Mozilla Compatible Agent 5   2131
# 2012-07                    Opera 11    255
# 2012-07                    Opera 12   1652
# 2012-07                Opera Mini 4    182
# 2012-07                Opera Mini 6     96
# 2012-07                Opera Mini 7     93
# 2012-07                  Opera Mobi     50
# 2012-07                  RockMelt 0     64
# 2012-07                  Safari 52X     75
# 2012-07                  Safari 53X  17405
# 2012-07                 Safari 65XX   1588
# 2012-07                 Safari 75XX  11690
# 2012-08         Android Browser 53X   3635
# 2012-08                   Chrome 10    133
# 2012-08                   Chrome 11    161
# 2012-08                   Chrome 12    455
# 2012-08                   Chrome 13     79
# 2012-08                   Chrome 14    158
# 2012-08                   Chrome 15    403
# 2012-08                   Chrome 16    480
# 2012-08                   Chrome 17    708
# 2012-08                   Chrome 18   2111
#                                 ...    ...
#
# [1279 rows x 2 columns]

# %%
languages = df[ df['Statistic']=='Languages' ]
languages = languages.set_index(['Period'])
languages = languages[['Value']]
languages
# Out:
#           Value
# Period
# 2012-07     565
# 2012-07      97
# 2012-07      77
# 2012-07     116
# 2012-07     388
# 2012-07     154
# 2012-07    1615
# 2012-07    2334
# 2012-07     526
# 2012-07     148
# 2012-07    5246
# 2012-07     111
# 2012-07   76709
# 2012-07      77
# 2012-07  264257
# 2012-07     266
# 2012-07    2064
# 2012-07     195
# 2012-07      71
# 2012-07    1275
# 2012-07     139
# 2012-07      62
# 2012-07    4583
# 2012-07     580
# 2012-07      75
# 2012-07     123
# 2012-07      98
# 2012-07    1547
# 2012-07     960
# 2012-07    1382
# 2012-07     123
# 2012-07    2317
# 2012-07      65
# 2012-07      58
# 2012-07     128
# 2012-07      63
# 2012-07    1101
# 2012-07     208
# 2012-07     904
# 2012-07      61
# 2012-07      86
# 2012-07     686
# 2012-07     138
# 2012-07     106
# 2012-07      79
# 2012-07     891
# 2012-07     255
# 2012-07     109
# 2012-07      62
# 2012-07     182
# 2012-07     112
# 2012-07      76
# 2012-07     499
# 2012-07     199
# 2012-07     101
# 2012-07      53
# 2012-07    5035
# 2012-07      85
# 2012-07    1786
# 2012-08     647
#             ...
#
# [1152 rows x 1 columns]

# %%
import json
from pprint import pprint
# orient = split records columns values index
orient = 'index'
#pprint( json.loads(  ) )
languages.to_json(orient=orient)
# Out:
# '{"["2012-07","(not set)"]":{"Value":565.0},"["2012-07","ar"]":{"Value":97.0},"["2012-07","bg"]":{"Value":77.0},"["2012-07","ca"]":{"Value":116.0},"["2012-07","cs"]":{"Value":388.0},"["2012-07","da"]":{"Value":154.0},"["2012-07","de"]":{"Value":1615.0},"["2012-07","de-de"]":{"Value":2334.0},"["2012-07","el"]":{"Value":526.0},"["2012-07","el-gr"]":{"Value":148.0},"["2012-07","en"]":{"Value":5246.0},"["2012-07","en-au"]":{"Value":111.0},"["2012-07","en-gb"]":{"Value":76709.0},"["2012-07","en-ie"]":{"Value":77.0},"["2012-07","en-us"]":{"Value":264257.0},"["2012-07","en_gb"]":{"Value":266.0},"["2012-07","es"]":{"Value":2064.0},"["2012-07","es-419"]":{"Value":195.0},"["2012-07","es-cl"]":{"Value":71.0},"["2012-07","es-es"]":{"Value":1275.0},"["2012-07","fi"]":{"Value":139.0},"["2012-07","fi-fi"]":{"Value":62.0},"["2012-07","fr"]":{"Value":4583.0},"["2012-07","fr-fr"]":{"Value":580.0},"["2012-07","he"]":{"Value":75.0},"["2012-07","hu"]":{"Value":123.0},"["2012-07","hu-hu"]":{"Value":98.0},"["2012-07","it"]":{"Value":1547.0},"["2012-07","it-it"]":{"Value":960.0},"["2012-07","ja"]":{"Value":1382.0},"["2012-07","ja-jp"]":{"Value":123.0},"["2012-07","ko"]":{"Value":2317.0},"["2012-07","ko-kr"]":{"Value":65.0},"["2012-07","lt"]":{"Value":58.0},"["2012-07","nb"]":{"Value":128.0},"["2012-07","nb-no"]":{"Value":63.0},"["2012-07","nl"]":{"Value":1101.0},"["2012-07","nl-nl"]":{"Value":208.0},"["2012-07","pl"]":{"Value":904.0},"["2012-07","pl-pl"]":{"Value":61.0},"["2012-07","pt"]":{"Value":86.0},"["2012-07","pt-br"]":{"Value":686.0},"["2012-07","pt-pt"]":{"Value":138.0},"["2012-07","ro"]":{"Value":106.0},"["2012-07","ro-ro"]":{"Value":79.0},"["2012-07","ru"]":{"Value":891.0},"["2012-07","ru-ru